# %%
# load the variables from .env file
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
result = prompty.execute(
    prompt=r"C:\Users\selshafey\OneDrive - Microsoft\FitForm\prompts\workout_program.prompty"
)

# %%
result
# Out:
# '{\n  "weeklyWorkoutPlan": {\n    "summary": {\n      "programOverview": "This is a 4-day-per-week, full-body strength and endurance program designed for a busy intermediate-level adult aiming for general fitness and weight loss. The plan uses bodyweight and resistance band exercises, is tailored to be performed at home with minimal equipment, and fits into 45-minute sessions. Each session includes warm-up, main workout, and cool-down, with rest and active recovery days to support sustainability and injury prevention.",\n      "weeklyVolume": "Approx. 3 hours of structured workouts plus 2+ hours of active recovery",\n      "progressionStrategy": "Gradually increase reps, sets, or resistance band tension as exercises become easier. Every 2-4 weeks, introduce more challenging variations (e.g., single-leg, tempo work), or reduce rest periods for increased intensity.",\n      "safetyNotes": "Warm up thoroughly before each session. Use controlled movements, especially for lower body and c
# ...

# %%
import prompty.azure
import os

result = prompty.execute(
    prompt=r"C:\Users\selshafey\OneDrive - Microsoft\FitForm\prompts\meal_prep.prompty",
    inputs={
        "goal": "Weight Loss",
        "sub_goals": "Increase Fibre Intake, Reduce Sugar Consumption",
        "height": "160",
        "weight": "70",
        "age": "30",
        "gender": "Female",
        "activity_level": "Lightly Active",
        "allergies": "Peanuts, Gluten",
        "preferences": "Vegetarian, Low Carb",
        "diseases": "Diabetes",
        "budget": "Medium",
        "cooking_time": "30 minutes per day",
    }
)

print(result)
# Out:
# {
#   "weeklyMealPlan": {
#     "Summary": {
#       "targetCalories": "1300",
#       "targetProtein": "90",
#       "targetCarbs": "80",
#       "targetFat": "60"
#     },
#     "Monday": {
#       "Breakfast": {
#         "name": "Vegetable Omelette",
#         "recipe": "1. Whisk 2 eggs. 2. Sauté 1/4 cup diced bell pepper, 1/4 cup diced tomato, and 1/4 cup spinach in 1 tsp olive oil. 3. Add eggs, cook until set.",
#         "ingredients": ["2 large eggs", "1/4 cup bell pepper", "1/4 cup tomato", "1/4 cup spinach", "1 tsp olive oil", "salt", "pepper"],
#         "macros": { "calories": 210, "protein": 18, "carbs": 6, "fat": 13 }
#       },
#       "Lunch": {
#         "name": "Chickpea & Avocado Salad",
#         "recipe": "1. Rinse 1/2 cup canned chickpeas. 2. Mix with 1/2 avocado, 1 cup mixed greens, 1/4 cup cucumber, lemon juice, salt, pepper.",
# ...

# %%
# Parse the result string into a Python dictionary
import ast

ast.literal_eval(result)
# Out:
# {'weeklyMealPlan': {'Summary': {'targetCalories': '1300',
#    'targetProtein': '90',
#    'targetCarbs': '80',
#    'targetFat': '60'},
#   'Monday': {'Breakfast': {'name': 'Vegetable Omelette',
#     'recipe': '1. Whisk 2 eggs. 2. Sauté 1/4 cup diced bell pepper, 1/4 cup diced tomato, and 1/4 cup spinach in 1 tsp olive oil. 3. Add eggs, cook until set.',
#     'ingredients': ['2 large eggs',
#      '1/4 cup bell pepper',
#      '1/4 cup tomato',
#      '1/4 cup spinach',
#      '1 tsp olive oil',
#      'salt',
#      'pepper'],
#     'macros': {'calories': 210, 'protein': 18, 'carbs': 6, 'fat': 13}},
#    'Lunch': {'name': 'Chickpea & Avocado Salad',
#     'recipe': '1. Rinse 1/2 cup canned chickpeas. 2. Mix with 1/2 avocado, 1 cup mixed greens, 1/4 cup cucumber, lemon juice, salt, pepper.',
#     'ingredients': ['1/2 cup canned chickpeas',
#      '1/2 avocado',
#      '1 cup mixed greens',
#      '1/4 cup cucumber',
#      '1 tbsp lemon juice',
#      'salt',
#      'pepper'],
# ...
